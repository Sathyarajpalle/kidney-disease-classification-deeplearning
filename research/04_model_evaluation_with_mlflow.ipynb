# %%
import os

# %%
# %pwd
# Out:
# 'c:\\DL Proj\\kidney-disease-classification-deeplearning\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\DL Proj\\kidney-disease-classification-deeplearning'

# %%
import tensorflow as tf

# %%
model = tf.keras.models.load_model("artifacts/training/model.h5")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model = tf.keras.models.load_model("artifacts/training/model.h5")
#
# File c:\Users\Palle Shashank\miniconda3\envs\kidney\lib\site-packages\keras\saving\saving_api.py:212, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     204     return saving_lib.load_model(
#     205         filepath,
#     206         custom_objects=custom_objects,
#     207         compile=compile,
#     208         safe_mode=safe_mode,
#     209     )
#     211 # Legacy case.
# --> 212 return legacy_sm_saving_lib.load_model(
#     213     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     214 )
#
# File c:\Users\Palle Shashank\miniconda3\envs\kidney\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
# ...
